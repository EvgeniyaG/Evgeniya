# %%
import pandas as pd

Location = r'C:\Users\GBTC405013ur\Downloads\titanic3.xls'
print(Location)
# Out:
# C:\Users\GBTC405013ur\Downloads\titanic3.xls

# %%
df = pd.read_excel(Location)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
    
df['gender_val']=df['sex'].apply(score_to_numeric)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  gender_val
# ...

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body   gender_val
# count  1308.000000  121.000000  1309.000000
# mean     33.295479  160.809917     0.355997
# std      51.758668   97.696922     0.478997
# min       0.000000    1.000000     0.000000
# 25%       7.895800   72.000000     0.000000
# 50%      14.454200  155.000000     0.000000
# ...

# %%
df_female=df[df['sex']=='female']
df_female_firstclass = df_female[df_female['pclass']==1]
df_female_firstclass.describe()
# Out:
#        pclass    survived         age       sibsp       parch        fare  \
# count   144.0  144.000000  133.000000  144.000000  144.000000  144.000000
# mean      1.0    0.965278   37.037594    0.555556    0.472222  109.412385
# std       0.0    0.183714   14.272460    0.666667    0.774998   82.885854
# min       1.0    0.000000    2.000000    0.000000    0.000000   25.700000
# 25%       1.0    1.000000   24.000000    0.000000    0.000000   55.441700
# 50%       1.0    1.000000   36.000000    0.000000    0.000000   80.929150
# 75%       1.0    1.000000   48.000000    1.000000    1.000000  135.919775
# max       1.0    1.000000   76.000000    3.000000    4.000000  512.329200
#
#        body
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
surv_df = df[df['survived']==1]

# %%
surv_df.describe()
# Out:
#            pclass  survived         age       sibsp       parch        fare  \
# count  500.000000     500.0  427.000000  500.000000  500.000000  500.000000
# mean     1.962000       1.0   28.918228    0.462000    0.476000   49.361184
# std      0.872972       0.0   15.061481    0.685197    0.776292   68.648795
# min      1.000000       1.0    0.166700    0.000000    0.000000    0.000000
# 25%      1.000000       1.0   20.000000    0.000000    0.000000   11.214600
# 50%      2.000000       1.0   28.000000    0.000000    0.000000   26.000000
# 75%      3.000000       1.0   38.000000    1.000000    1.000000   57.750000
# max      3.000000       1.0   80.000000    4.000000    5.000000  512.329200
#
#        body
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
df_firstclass = df[df['pclass']==1]

# %%
df_firstclass.describe()
# Out:
#        pclass    survived         age       sibsp       parch        fare  \
# count   323.0  323.000000  284.000000  323.000000  323.000000  323.000000
# mean      1.0    0.619195   39.159918    0.436533    0.365325   87.508992
# std       0.0    0.486338   14.548059    0.609064    0.715602   80.447178
# min       1.0    0.000000    0.916700    0.000000    0.000000    0.000000
# 25%       1.0    0.000000   28.000000    0.000000    0.000000   30.695800
# 50%       1.0    1.000000   39.000000    0.000000    0.000000   60.000000
# 75%       1.0    1.000000   50.000000    1.000000    0.500000  107.662500
# max       1.0    1.000000   80.000000    3.000000    4.000000  512.329200
#
#              body
# count   35.000000
# mean   162.828571
# std     82.652172
# min     16.000000
# 25%    109.500000
# 50%    166.000000
# 75%    233.000000
# max    307.000000

# %%
df_cheapseats=df[df["pclass"] >=2]

# %%
df_cheapseats.describe()
# Out:
#            pclass    survived         age       sibsp       parch        fare  \
# count  986.000000  986.000000  762.000000  986.000000  986.000000  985.000000
# mean     2.719067    0.304260   26.422900    0.519270    0.391481   15.517850
# std      0.449683    0.460327   12.746265    1.147999    0.909559   12.625912
# min      2.000000    0.000000    0.166700    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   19.000000    0.000000    0.000000    7.854200
# 50%      3.000000    0.000000   25.000000    0.000000    0.000000   10.500000
# 75%      3.000000    1.000000   33.000000    1.000000    0.000000   19.258300
# max      3.000000    1.000000   74.000000    8.000000    9.000000   73.500000
#
#              body
# count   86.000000
# mean   159.988372
# std    103.633687
# min      1.000000
# 25%     68.250000
# 50%    154.000000
# 75%    260.750000
# max    328.000000

# %%
df.corr()
# Out:
#               pclass  survived       age     sibsp     parch      fare  \
# pclass      1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629
# survived   -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265
# age        -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739
# sibsp       0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238
# parch       0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539
# fare       -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000
# body       -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110
# gender_val -0.124617  0.528693 -0.063646  0.109609  0.213125  0.185523
#
#                 body  gender_val
# pclass     -0.034642   -0.124617
# survived         NaN    0.528693
# age         0.058809   -0.063646
# sibsp      -0.099961    0.109609
# parch       0.051099    0.213125
# fare       -0.043110    0.185523
# body        1.000000    0.015903
# gender_val  0.015903    1.000000
